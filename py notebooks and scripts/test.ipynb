# %%
import jwt
import time

private_key = open("/home/samu/ed25519-private.pem").read()

payload = {
    "sub": "2B2F72D2M7",
    "iat": int(time.time()),
    "exp": int(time.time()) + 86000
}

headers = {
    "alg": "EdDSA",
    "kid": "C5B8UBYGVX"
}

token = jwt.encode(
    payload,
    private_key,
    algorithm="EdDSA",
    headers=headers
)

print(token)
# Out:
# eyJhbGciOiJFZERTQSIsImtpZCI6IkM1QjhVQllHVlgiLCJ0eXAiOiJKV1QifQ.eyJzdWIiOiIyQjJGNzJEMk03IiwiaWF0IjoxNzc3MjMzNTEwLCJleHAiOjE3NzczMTk1MTB9.Tne_2LjbXmoHf1x9Kykr8xlGAo3kxb13FblVaxROK6uRLV1oyj2r87DD0U1_MhAjHcGfkJ1l-XOZO9qCcwtxDA

# %%
from aicsimageio import AICSImage

img = AICSImage("/home/samu/Documents/Laurea/Data/input/OSCC_PATIENTS/SOSPENSIONE/PR2/New-01.czi")
print(img.dims)        # es. <Dimensions [T: 1, C: 1, Z: 1, Y: 968, X: 1292]>
print(img.shape)       # es. (1, 1, 1, 968, 1292)
print(img.channel_names)
# Out:
# <Dimensions [T: 1, C: 3, Z: 1, Y: 2208, X: 3216]>
# (1, 3, 1, 2208, 3216)
# [np.str_('DIC'), np.str_('TaCFP'), np.str_('Phase')]

# %%
from pathlib import Path

stem = Path("New-01b.czi - TR1").stem
print(stem)
# Out:
# New-01b
